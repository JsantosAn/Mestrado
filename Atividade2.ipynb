# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

db = pd.read_csv("/content/drive/My Drive/Datasets/CarPrice_Assignment.csv")
db.head()

# %%
db.keys()
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
data = db.copy()
data.head()

# %%
data = data.drop(columns=[ 'symboling', 'CarName', 'fueltype', 'aspiration','doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase','cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke','compressionratio', 'peakrpm', 'citympg', 'highwaympg','enginetype','curbweight','price'])

# %%
X = data
y = db.price
X.shape, y.shape
# Out:
# ((205, 5), (205,))

# %%
import matplotlib.pyplot as plt
for i in range(X.shape[1]):
    print(i)
    plt.scatter(X.iloc[:,i], y)
    plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
X4 = X.iloc[:,1:2]
plt.scatter(X4,y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

modelo_lr = LinearRegression()
plt.scatter(X4, y)

modelo_lr.fit(X4, y)

ypred = modelo_lr.predict(X4)
erro = rmse(y, ypred)
print(f"rmse final: {erro}")
plt.plot(X4, ypred, '.r', alpha=0.5)

plt.show()
modelo_lr.intercept_, modelo_lr.coef_
# Out:
# rmse final: 5821.550895415822
# (-63690.67161230283, array([442.21606295]))

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

def rmse(y, ypred):
    mse = mean_squared_error(y,ypred)
    return sqrt(mse)

rmse(y, ypred)
# Out:
# 5821.550895415822

# %%
plt.scatter(X4, y)
plt.plot(X4, ypred, 'r')
plt.show()
